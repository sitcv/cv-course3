# %% [markdown]
# # # cannyエッジ検出法を用いて、noise_lena.png画像内のエッジを検出する
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sitcv/cv-course3/blob/main/edge-detection.ipynb)

# %%
# Colab setup: fetch sample images if missing
import os, urllib.request

BASE = "https://raw.githubusercontent.com/sitcv/cv-course2/main/"
for name in ["noisy_lena.png"]:
    if not os.path.exists(name):
        urllib.request.urlretrieve(BASE + name, name)
        print("downloaded", name)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# ノイズの多い画像を読み込む
image = cv2.imread('noisy_lena.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# グレースケールに変換
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# ガウスぼかしを適用してノイズを低減し、エッジ検出の精度を高める
image_blur = cv2.GaussianBlur(image_gray, (5, 5), 1.5)

# Cannyエッジ検出を適用する
edges = cv2.Canny(image_blur, 100, 200, apertureSize=3)

# 元の画像とエッジ検出画像を表示する
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image_blur, cmap='gray')
plt.title('Blurred Image')
plt.axis('off')

#　エッジ検出された画像を表示する
plt.subplot(1, 2, 2)
plt.imshow(edges, cmap='gray')
plt.title('Edge Detected Image')
plt.axis('off')

plt.show()
